# %% [markdown]
# # Assignment 3 Part 1A Introduction: Multi-label Image Classification

# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir("gdrive/My Drive/assignment3_p1")
# Out:
# Mounted at /content/gdrive

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torchvision

from torchvision import transforms
from sklearn.metrics import average_precision_score
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
from kaggle_submission import output_submission_csv
from classifier import SimpleClassifier, Classifier#, AlexNet
from voc_dataloader import VocDataset, VOC_CLASSES

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import shutil 
shutil.copyfile("VOCtrainval_06-Nov-2007.tar", "/content/VOCtrainval_06-Nov-2007.tar")
# !tar -xf "/content/VOCtrainval_06-Nov-2007.tar" -C "/content/" 
shutil.move("/content/VOCdevkit/", "/content/VOCdevkit_2007")

shutil.copyfile("VOCtest_06-Nov-2007.tar", "/content/VOCtest_06-Nov-2007.tar")
# !tar -xf "/content/VOCtest_06-Nov-2007.tar" -C "/content/" 
shutil.move("/content/VOCdevkit/VOC2007", "/content/VOCdevkit_2007/VOC2007test")
# Out:
# '/content/VOCdevkit_2007/VOC2007test'

# %% [markdown]
# # Multi-label Classification
# In this assignment, you train a classifier to do multi-label classificaton on the PASCAL VOC 2007 dataset. The dataset has 20 different class which can appear in any given image. Your classifier will predict whether each class appears in an image. This task is slightly different from exclusive multiclass classification like the ImageNet competition where only a single most appropriate class is predicted for an image.
#
# ## Part 1A
# You will use this notebook to warm up with pytorch and the code+dataset that we will use for assignment3.
#
# ### What to do
# In part 1A, You are asked to run below experiments. You don't need to change hyperparameters for this Part 1A's experiments. (the following code provides everything that you will need.)
# 1. to train a simple network (defined in ```classifiers.py```)
# 2. to train the AlexNet (PyTorch built-in)
#     - from scratch
#     - finetuning AlexNet pretrained on ImageNet
#
#
#
# ### What to submit
# We ask you to run the following code and report the results in your homework submission. You may want to leverage this part 1A get yourself familiar with PyTorch.
#
# You will the need the numbers and plots this notebook outputs for reports, but you are not required to submit this notebook as a printed pdf.

# %% [markdown]
# ## Reading Pascal Data

# %% [markdown]
# ### Loading Training Data

# %% [markdown]
# In the following cell we will load the training data and also apply some transforms to the data.

# %%
# Transforms applied to the training data
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std= [0.229, 0.224, 0.225])

train_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize
        ])

# %%
ds_train = VocDataset('/content/VOCdevkit_2007/VOC2007','train',train_transform)

# %% [markdown]
# ### Loading Validation Data

# %% [markdown]
# We will load the test data for the PASCAL VOC 2007 dataset. Do __NOT__ add data augmentation transforms to validation data.

# %%
# Transforms applied to the testing data
test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])

# %%
ds_val = VocDataset('/content/VOCdevkit_2007/VOC2007','val',test_transform)

# %% [markdown]
# ### Visualizing the Data
#
# PASCAL VOC has bounding box annotations in addition to class labels. Use the following code to visualize some random examples and corresponding annotations from the train set.

# %%
for i in range(5):
    idx = np.random.randint(0, len(ds_train.names)+1)
    _imgpath = os.path.join('/content/VOCdevkit_2007/VOC2007', 'JPEGImages', ds_train.names[idx]+'.jpg')
    img = Image.open(_imgpath).convert('RGB')
    draw = ImageDraw.Draw(img)
    for j in range(len(ds_train.box_indices[idx])):
        obj = ds_train.box_indices[idx][j]
        draw.rectangle(list(obj), outline=(255,0,0))
        draw.text(list(obj[0:2]), ds_train.classes[ds_train.label_order[idx][j]], fill=(0,255,0))
    plt.figure(figsize = (10,10))
    plt.imshow(np.array(img))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Classification

# %%
# declare what device to use: gpu/cpu
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=50, 
                                               shuffle=True,
                                               num_workers=1)

# %%
val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=50, 
                                               shuffle=True,
                                               num_workers=1)

# %%
def train_classifier(train_loader, classifier, criterion, optimizer):
    classifier.train()
    loss_ = 0.0
    losses = []
    for i, (images, labels, _) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        logits = classifier(images)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        losses.append(loss)
    return torch.stack(losses).mean().item()

# %%
def test_classifier(test_loader, classifier, criterion, print_ind_classes=True, print_total=True):
    classifier.eval()
    losses = []
    with torch.no_grad():
        y_true = np.zeros((0,21))
        y_score = np.zeros((0,21))
        for i, (images, labels, _) in enumerate(test_loader):
            images, labels = images.to(device), labels.to(device)
            logits = classifier(images)
            y_true = np.concatenate((y_true, labels.cpu().numpy()), axis=0)
            y_score = np.concatenate((y_score, logits.cpu().numpy()), axis=0)
            loss = criterion(logits, labels)
            losses.append(loss.item())
        aps = []
        # ignore first class which is background
        for i in range(1, y_true.shape[1]):
            ap = average_precision_score(y_true[:, i], y_score[:, i])
            if print_ind_classes:
                print('-------  Class: {:<12}     AP: {:>8.4f}  -------'.format(VOC_CLASSES[i], ap))
            aps.append(ap)
        
        mAP = np.mean(aps)
        test_loss = np.mean(losses)
        if print_total:
            print('mAP: {0:.4f}'.format(mAP))
            print('Avg loss: {}'.format(test_loss))
        
    return mAP, test_loss, aps

# %%
# plot functions
def plot_losses(train, val, test_frequency, num_epochs):
    plt.plot(train, label="train")
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, val, label="val")
    plt.title("Loss Plot")
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()
    
def plot_mAP(train, val, test_frequency, num_epochs):
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, train, label="train")
    plt.plot(indices, val, label="val")
    plt.title("mAP Plot")
    plt.ylabel("mAP")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()

# %% [markdown]
# ## Training the network
#
# The simple network you are given as is will allow you to reach around 0.15-0.2 mAP. In this project, you will find ways to design a better network. Save plots and final test mAP scores as you will be adding these to the writeup.

# %%
def train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency=5):
    train_losses = []
    train_mAPs = []
    val_losses = []
    val_mAPs = []

    for epoch in range(1,num_epochs+1):
        print("Starting epoch number " + str(epoch))
        train_loss = train_classifier(train_loader, classifier, criterion, optimizer)
        train_losses.append(train_loss)
        print("Loss for Training on Epoch " +str(epoch) + " is "+ str(train_loss))
        if(epoch%test_frequency==0 or epoch==1):
            mAP_train, _, _ = test_classifier(train_loader, classifier, criterion, False, False)
            train_mAPs.append(mAP_train)
            mAP_val, val_loss, _ = test_classifier(val_loader, classifier, criterion)
            print('Evaluating classifier')
            print("Mean Precision Score for Testing on Epoch " +str(epoch) + " is "+ str(mAP_val))
            val_losses.append(val_loss)
            val_mAPs.append(mAP_val)
    
    return classifier, train_losses, val_losses, train_mAPs, val_mAPs

# %%
classifier = SimpleClassifier().to(device)
# You can can use this function to reload a network you have already saved previously
#classifier.load_state_dict(torch.load('voc_classifier.pth'))

# %%
criterion = nn.MultiLabelSoftMarginLoss()
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)

# %%
# Training the Classifier
num_epochs = 20
test_frequency = 5

classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.5202638506889343
# -------  Class: aeroplane        AP:   0.1136  -------
# -------  Class: bicycle          AP:   0.0499  -------
# -------  Class: bird             AP:   0.1154  -------
# -------  Class: boat             AP:   0.0863  -------
# -------  Class: bottle           AP:   0.0404  -------
# -------  Class: bus              AP:   0.0296  -------
# -------  Class: car              AP:   0.1095  -------
# -------  Class: cat              AP:   0.0887  -------
# -------  Class: chair            AP:   0.1147  -------
# -------  Class: cow              AP:   0.0330  -------
# -------  Class: diningtable      AP:   0.0519  -------
# -------  Class: dog              AP:   0.1196  -------
# -------  Class: horse            AP:   0.0531  -------
# -------  Class: motorbike        AP:   0.0421  -------
# -------  Class: person           AP:   0.3431  -------
# -------  Class: pottedplant      AP:   0.0461  -------
# -------  Class: sheep            AP:   0.0315  -------
# -------  Class: sofa             AP:   0.0912  -------
# -------  Class: train            AP:   0.0361  -------
# -------  Class: tvmonitor        AP:   0.0506  -------
# mAP: 0.0823
# Avg loss: 0.2753150281952877
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.08231459015749383
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.2518808841705322
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.2433629333972931
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.240470752120018
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.23821863532066345
# -------  Class: aeroplane        AP:   0.0894  -------
# -------  Class: bicycle          AP:   0.0445  -------
# -------  Class: bird             AP:   0.1141  -------
# -------  Class: boat             AP:   0.0667  -------
# -------  Class: bottle           AP:   0.0425  -------
# -------  Class: bus              AP:   0.0280  -------
# -------  Class: car              AP:   0.1133  -------
# -------  Class: cat              AP:   0.1126  -------
# -------  Class: chair            AP:   0.1286  -------
# -------  Class: cow              AP:   0.0329  -------
# -------  Class: diningtable      AP:   0.0570  -------
# -------  Class: dog              AP:   0.1332  -------
# -------  Class: horse            AP:   0.0522  -------
# -------  Class: motorbike        AP:   0.0413  -------
# -------  Class: person           AP:   0.4056  -------
# -------  Class: pottedplant      AP:   0.0463  -------
# -------  Class: sheep            AP:   0.0354  -------
# -------  Class: sofa             AP:   0.1066  -------
# -------  Class: train            AP:   0.0369  -------
# -------  Class: tvmonitor        AP:   0.0541  -------
# mAP: 0.0871
# Avg loss: 0.23688548043662427
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.08705625197044205
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.23936043679714203
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.23814859986305237
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.2376316338777542
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.23264126479625702
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.23149913549423218
# -------  Class: aeroplane        AP:   0.2109  -------
# -------  Class: bicycle          AP:   0.0475  -------
# -------  Class: bird             AP:   0.1182  -------
# -------  Class: boat             AP:   0.1344  -------
# -------  Class: bottle           AP:   0.0549  -------
# -------  Class: bus              AP:   0.0367  -------
# -------  Class: car              AP:   0.1765  -------
# -------  Class: cat              AP:   0.1322  -------
# -------  Class: chair            AP:   0.1672  -------
# -------  Class: cow              AP:   0.0363  -------
# -------  Class: diningtable      AP:   0.0732  -------
# -------  Class: dog              AP:   0.1345  -------
# -------  Class: horse            AP:   0.0587  -------
# -------  Class: motorbike        AP:   0.0431  -------
# -------  Class: person           AP:   0.4872  -------
# -------  Class: pottedplant      AP:   0.0459  -------
# -------  Class: sheep            AP:   0.0383  -------
# -------  Class: sofa             AP:   0.1406  -------
# -------  Class: train            AP:   0.0888  -------
# -------  Class: tvmonitor        AP:   0.0607  -------
# mAP: 0.1143
# Avg loss: 0.23013529911929487
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.11429260277473167
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.23080560564994812
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.22869926691055298
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.22689390182495117
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.22840680181980133
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.2252979725599289
# -------  Class: aeroplane        AP:   0.3154  -------
# -------  Class: bicycle          AP:   0.0574  -------
# -------  Class: bird             AP:   0.1047  -------
# -------  Class: boat             AP:   0.2140  -------
# -------  Class: bottle           AP:   0.0711  -------
# -------  Class: bus              AP:   0.0496  -------
# -------  Class: car              AP:   0.2139  -------
# -------  Class: cat              AP:   0.1494  -------
# -------  Class: chair            AP:   0.2142  -------
# -------  Class: cow              AP:   0.0469  -------
# -------  Class: diningtable      AP:   0.1167  -------
# -------  Class: dog              AP:   0.1450  -------
# -------  Class: horse            AP:   0.0798  -------
# -------  Class: motorbike        AP:   0.0520  -------
# -------  Class: person           AP:   0.4906  -------
# -------  Class: pottedplant      AP:   0.0591  -------
# -------  Class: sheep            AP:   0.0412  -------
# -------  Class: sofa             AP:   0.1745  -------
# -------  Class: train            AP:   0.1006  -------
# -------  Class: tvmonitor        AP:   0.0840  -------
# mAP: 0.1390
# Avg loss: 0.22598318872498532
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.13900532189358333
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.2228703498840332
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.22301889955997467
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.22076742351055145
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.2182944267988205
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.21852432191371918
# -------  Class: aeroplane        AP:   0.3582  -------
# -------  Class: bicycle          AP:   0.0699  -------
# -------  Class: bird             AP:   0.1063  -------
# -------  Class: boat             AP:   0.2642  -------
# -------  Class: bottle           AP:   0.0779  -------
# -------  Class: bus              AP:   0.0732  -------
# -------  Class: car              AP:   0.2339  -------
# -------  Class: cat              AP:   0.1477  -------
# -------  Class: chair            AP:   0.2435  -------
# -------  Class: cow              AP:   0.0606  -------
# -------  Class: diningtable      AP:   0.1777  -------
# -------  Class: dog              AP:   0.1468  -------
# -------  Class: horse            AP:   0.1222  -------
# -------  Class: motorbike        AP:   0.0658  -------
# -------  Class: person           AP:   0.5009  -------
# -------  Class: pottedplant      AP:   0.0895  -------
# -------  Class: sheep            AP:   0.0406  -------
# -------  Class: sofa             AP:   0.1883  -------
# -------  Class: train            AP:   0.1346  -------
# -------  Class: tvmonitor        AP:   0.1174  -------
# mAP: 0.1610
# Avg loss: 0.22207728203605204
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.16095072385777112

# %%
# Compare train and validation metrics
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
# Save the clssifier network
# Suggestion: you can save checkpoints of your network during training and reload them later
torch.save(classifier.state_dict(), './voc_simple_classifier.pth')

# %% [markdown]
# # Evaluate on test set

# %%
ds_test = VocDataset('/content/VOCdevkit_2007/VOC2007test','test', test_transform)

test_loader = torch.utils.data.DataLoader(dataset=ds_test,
                                               batch_size=50, 
                                               shuffle=False,
                                               num_workers=1)

# Transforms applied to the testing data
test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])

mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
# Out:
# -------  Class: aeroplane        AP:   0.3316  -------
# -------  Class: bicycle          AP:   0.0589  -------
# -------  Class: bird             AP:   0.1077  -------
# -------  Class: boat             AP:   0.2097  -------
# -------  Class: bottle           AP:   0.0756  -------
# -------  Class: bus              AP:   0.0616  -------
# -------  Class: car              AP:   0.2792  -------
# -------  Class: cat              AP:   0.1072  -------
# -------  Class: chair            AP:   0.2409  -------
# -------  Class: cow              AP:   0.0696  -------
# -------  Class: diningtable      AP:   0.1200  -------
# -------  Class: dog              AP:   0.1618  -------
# -------  Class: horse            AP:   0.1143  -------
# -------  Class: motorbike        AP:   0.0725  -------
# -------  Class: person           AP:   0.5139  -------
# -------  Class: pottedplant      AP:   0.0760  -------
# -------  Class: sheep            AP:   0.0886  -------
# -------  Class: sofa             AP:   0.1960  -------
# -------  Class: train            AP:   0.1623  -------
# -------  Class: tvmonitor        AP:   0.0926  -------
# mAP: 0.1570
# Avg loss: 0.21796246588230134

# %%
output_submission_csv('my_solution.csv', test_aps)

# %% [markdown]
# # AlexNet Baselines (From Scratch)

# %% [markdown]
# AlexNet was one of the earliest deep learning models to have success in classification. In this section we will be running classification with AlexNet as a baseline. Furthermore, we will run an ImageNet-pretrained AlexNet to observe the impact of well-trained features. Save plots and final test mAP scores as you will be adding these to the writeup.

# %% [markdown]
# ## Running AlexNet
#
# In this section, we train AlexNet from scratch using the same hyperparameters as our previous experiment.

# %%
num_epochs = 20
test_frequency = 5

# Change classifier to AlexNet
classifier = torchvision.models.alexnet(pretrained=False)
classifier.classifier._modules['6'] = nn.Linear(4096, 21)   
classifier = classifier.to(device)

criterion = nn.MultiLabelSoftMarginLoss()

optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)

# %%
classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.5716398358345032
# -------  Class: aeroplane        AP:   0.1720  -------
# -------  Class: bicycle          AP:   0.0430  -------
# -------  Class: bird             AP:   0.0943  -------
# -------  Class: boat             AP:   0.1378  -------
# -------  Class: bottle           AP:   0.0370  -------
# -------  Class: bus              AP:   0.0292  -------
# -------  Class: car              AP:   0.1102  -------
# -------  Class: cat              AP:   0.1007  -------
# -------  Class: chair            AP:   0.1063  -------
# -------  Class: cow              AP:   0.0353  -------
# -------  Class: diningtable      AP:   0.0455  -------
# -------  Class: dog              AP:   0.1107  -------
# -------  Class: horse            AP:   0.0449  -------
# -------  Class: motorbike        AP:   0.0336  -------
# -------  Class: person           AP:   0.3258  -------
# -------  Class: pottedplant      AP:   0.0399  -------
# -------  Class: sheep            AP:   0.0348  -------
# -------  Class: sofa             AP:   0.0882  -------
# -------  Class: train            AP:   0.0400  -------
# -------  Class: tvmonitor        AP:   0.0483  -------
# mAP: 0.0839
# Avg loss: 0.2903645383376701
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.08388603415250848
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.2566540837287903
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.24995355308055878
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.24685561656951904
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.2420448511838913
# -------  Class: aeroplane        AP:   0.0982  -------
# -------  Class: bicycle          AP:   0.0451  -------
# -------  Class: bird             AP:   0.1110  -------
# -------  Class: boat             AP:   0.0988  -------
# -------  Class: bottle           AP:   0.0429  -------
# -------  Class: bus              AP:   0.0283  -------
# -------  Class: car              AP:   0.1095  -------
# -------  Class: cat              AP:   0.0943  -------
# -------  Class: chair            AP:   0.1259  -------
# -------  Class: cow              AP:   0.0343  -------
# -------  Class: diningtable      AP:   0.0569  -------
# -------  Class: dog              AP:   0.1166  -------
# -------  Class: horse            AP:   0.0479  -------
# -------  Class: motorbike        AP:   0.0371  -------
# -------  Class: person           AP:   0.3709  -------
# -------  Class: pottedplant      AP:   0.0458  -------
# -------  Class: sheep            AP:   0.0358  -------
# -------  Class: sofa             AP:   0.1000  -------
# -------  Class: train            AP:   0.0394  -------
# -------  Class: tvmonitor        AP:   0.0486  -------
# mAP: 0.0844
# Avg loss: 0.24407866918573193
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.08437210397536682
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.24019235372543335
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.2403949797153473
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.2443591058254242
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.23934204876422882
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.24115024507045746
# -------  Class: aeroplane        AP:   0.0832  -------
# -------  Class: bicycle          AP:   0.0478  -------
# -------  Class: bird             AP:   0.1173  -------
# -------  Class: boat             AP:   0.0932  -------
# -------  Class: bottle           AP:   0.0420  -------
# -------  Class: bus              AP:   0.0291  -------
# -------  Class: car              AP:   0.1130  -------
# -------  Class: cat              AP:   0.0934  -------
# -------  Class: chair            AP:   0.1300  -------
# -------  Class: cow              AP:   0.0353  -------
# -------  Class: diningtable      AP:   0.0577  -------
# -------  Class: dog              AP:   0.1191  -------
# -------  Class: horse            AP:   0.0503  -------
# -------  Class: motorbike        AP:   0.0395  -------
# -------  Class: person           AP:   0.3931  -------
# -------  Class: pottedplant      AP:   0.0485  -------
# -------  Class: sheep            AP:   0.0424  -------
# -------  Class: sofa             AP:   0.0983  -------
# -------  Class: train            AP:   0.0407  -------
# -------  Class: tvmonitor        AP:   0.0502  -------
# mAP: 0.0862
# Avg loss: 0.24045521020889282
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.08619087303209313
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.2397030144929886
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.2517925798892975
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.2522440254688263
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.24145232141017914
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.23700790107250214
# -------  Class: aeroplane        AP:   0.0770  -------
# -------  Class: bicycle          AP:   0.0509  -------
# -------  Class: bird             AP:   0.1238  -------
# -------  Class: boat             AP:   0.0839  -------
# -------  Class: bottle           AP:   0.0408  -------
# -------  Class: bus              AP:   0.0303  -------
# -------  Class: car              AP:   0.1180  -------
# -------  Class: cat              AP:   0.0907  -------
# -------  Class: chair            AP:   0.1325  -------
# -------  Class: cow              AP:   0.0363  -------
# -------  Class: diningtable      AP:   0.0582  -------
# -------  Class: dog              AP:   0.1187  -------
# -------  Class: horse            AP:   0.0530  -------
# -------  Class: motorbike        AP:   0.0414  -------
# -------  Class: person           AP:   0.4448  -------
# -------  Class: pottedplant      AP:   0.0514  -------
# -------  Class: sheep            AP:   0.0501  -------
# -------  Class: sofa             AP:   0.0964  -------
# -------  Class: train            AP:   0.0425  -------
# -------  Class: tvmonitor        AP:   0.0512  -------
# mAP: 0.0896
# Avg loss: 0.2352634203784606
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.0895957682739245
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.23832811415195465
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.23731300234794617
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.23917554318904877
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.23608843982219696
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.23914691805839539
# -------  Class: aeroplane        AP:   0.0788  -------
# -------  Class: bicycle          AP:   0.0548  -------
# -------  Class: bird             AP:   0.1332  -------
# -------  Class: boat             AP:   0.0800  -------
# -------  Class: bottle           AP:   0.0432  -------
# -------  Class: bus              AP:   0.0315  -------
# -------  Class: car              AP:   0.1275  -------
# -------  Class: cat              AP:   0.0899  -------
# -------  Class: chair            AP:   0.1457  -------
# -------  Class: cow              AP:   0.0371  -------
# -------  Class: diningtable      AP:   0.0652  -------
# -------  Class: dog              AP:   0.1182  -------
# -------  Class: horse            AP:   0.0558  -------
# -------  Class: motorbike        AP:   0.0444  -------
# -------  Class: person           AP:   0.4318  -------
# -------  Class: pottedplant      AP:   0.0546  -------
# -------  Class: sheep            AP:   0.0521  -------
# -------  Class: sofa             AP:   0.0971  -------
# -------  Class: train            AP:   0.0448  -------
# -------  Class: tvmonitor        AP:   0.0527  -------
# mAP: 0.0919
# Avg loss: 0.23685038966291092
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.09192505432574054

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print("Test mAP: ", mAP_test)
# Out:
# -------  Class: aeroplane        AP:   0.0634  -------
# -------  Class: bicycle          AP:   0.0540  -------
# -------  Class: bird             AP:   0.1027  -------
# -------  Class: boat             AP:   0.0564  -------
# -------  Class: bottle           AP:   0.0454  -------
# -------  Class: bus              AP:   0.0303  -------
# -------  Class: car              AP:   0.1295  -------
# -------  Class: cat              AP:   0.0866  -------
# -------  Class: chair            AP:   0.1348  -------
# -------  Class: cow              AP:   0.0426  -------
# -------  Class: diningtable      AP:   0.0535  -------
# -------  Class: dog              AP:   0.1234  -------
# -------  Class: horse            AP:   0.0531  -------
# -------  Class: motorbike        AP:   0.0397  -------
# -------  Class: person           AP:   0.4380  -------
# -------  Class: pottedplant      AP:   0.0506  -------
# -------  Class: sheep            AP:   0.0590  -------
# -------  Class: sofa             AP:   0.1027  -------
# -------  Class: train            AP:   0.0465  -------
# -------  Class: tvmonitor        AP:   0.0491  -------
# mAP: 0.0881
# Avg loss: 0.23325263917446137
# Test mAP:  0.08805538526140877

# %% [markdown]
# You should notice somewhat poor performance. You could try running AlexNet with an Adam optimizer instead with learning rate 1e-4 to see if that makes a difference. This experiment is not required for the writeup, but it may show you the importance of a good learning rate and optimizer.

# %% [markdown]
# ## Pretrained AlexNet

# %% [markdown]
# Here we look at the impact of pretrained features. This model's weights were trained on ImageNet, which is a much larger dataset. How do pretrained features perform on VOC? Why do you think there is such a large difference in performance?

# %%
num_epochs = 20
test_frequency = 5

# Load Pretrained AlexNet
classifier = torchvision.models.alexnet(pretrained=True)
classifier.classifier._modules['6'] = nn.Linear(4096, 21)   
classifier = classifier.to(device)
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-4df8aa71.pth
# HBox(children=(FloatProgress(value=0.0, max=244418560.0), HTML(value='')))

# %%
classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.22389498353004456
# -------  Class: aeroplane        AP:   0.7548  -------
# -------  Class: bicycle          AP:   0.5828  -------
# -------  Class: bird             AP:   0.7879  -------
# -------  Class: boat             AP:   0.6354  -------
# -------  Class: bottle           AP:   0.2943  -------
# -------  Class: bus              AP:   0.4793  -------
# -------  Class: car              AP:   0.7571  -------
# -------  Class: cat              AP:   0.6477  -------
# -------  Class: chair            AP:   0.5736  -------
# -------  Class: cow              AP:   0.3010  -------
# -------  Class: diningtable      AP:   0.4895  -------
# -------  Class: dog              AP:   0.6295  -------
# -------  Class: horse            AP:   0.6299  -------
# -------  Class: motorbike        AP:   0.6550  -------
# -------  Class: person           AP:   0.8971  -------
# -------  Class: pottedplant      AP:   0.2824  -------
# -------  Class: sheep            AP:   0.3621  -------
# -------  Class: sofa             AP:   0.4337  -------
# -------  Class: train            AP:   0.8285  -------
# -------  Class: tvmonitor        AP:   0.4438  -------
# mAP: 0.5733
# Avg loss: 0.14178236281754925
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.5732735310570589
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.12429598718881607
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.106147900223732
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.09458065032958984
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.09739984571933746
# -------  Class: aeroplane        AP:   0.8606  -------
# -------  Class: bicycle          AP:   0.6758  -------
# -------  Class: bird             AP:   0.8548  -------
# -------  Class: boat             AP:   0.7618  -------
# -------  Class: bottle           AP:   0.4077  -------
# -------  Class: bus              AP:   0.6066  -------
# -------  Class: car              AP:   0.7828  -------
# -------  Class: cat              AP:   0.7833  -------
# -------  Class: chair            AP:   0.6086  -------
# -------  Class: cow              AP:   0.4331  -------
# -------  Class: diningtable      AP:   0.5859  -------
# -------  Class: dog              AP:   0.7342  -------
# -------  Class: horse            AP:   0.7229  -------
# -------  Class: motorbike        AP:   0.8102  -------
# -------  Class: person           AP:   0.9081  -------
# -------  Class: pottedplant      AP:   0.4213  -------
# -------  Class: sheep            AP:   0.6462  -------
# -------  Class: sofa             AP:   0.5331  -------
# -------  Class: train            AP:   0.8955  -------
# -------  Class: tvmonitor        AP:   0.6501  -------
# mAP: 0.6841
# Avg loss: 0.11849110631966124
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.6841270698374585
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.08212927728891373
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.07300152629613876
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.05951497703790665
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.052267614752054214
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.04806201905012131
# -------  Class: aeroplane        AP:   0.8693  -------
# -------  Class: bicycle          AP:   0.7097  -------
# -------  Class: bird             AP:   0.8546  -------
# -------  Class: boat             AP:   0.7717  -------
# -------  Class: bottle           AP:   0.4212  -------
# -------  Class: bus              AP:   0.6186  -------
# -------  Class: car              AP:   0.8126  -------
# -------  Class: cat              AP:   0.7863  -------
# -------  Class: chair            AP:   0.6035  -------
# -------  Class: cow              AP:   0.5022  -------
# -------  Class: diningtable      AP:   0.6141  -------
# -------  Class: dog              AP:   0.7256  -------
# -------  Class: horse            AP:   0.7630  -------
# -------  Class: motorbike        AP:   0.8256  -------
# -------  Class: person           AP:   0.9094  -------
# -------  Class: pottedplant      AP:   0.4318  -------
# -------  Class: sheep            AP:   0.6349  -------
# -------  Class: sofa             AP:   0.5635  -------
# -------  Class: train            AP:   0.8957  -------
# -------  Class: tvmonitor        AP:   0.6471  -------
# mAP: 0.6980
# Avg loss: 0.12742464857942917
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.6980175352444313
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.04368257150053978
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.03641771897673607
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.03558092936873436
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.027402857318520546
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.023694345727562904
# -------  Class: aeroplane        AP:   0.8672  -------
# -------  Class: bicycle          AP:   0.6921  -------
# -------  Class: bird             AP:   0.8452  -------
# -------  Class: boat             AP:   0.7605  -------
# -------  Class: bottle           AP:   0.4060  -------
# -------  Class: bus              AP:   0.6254  -------
# -------  Class: car              AP:   0.7983  -------
# -------  Class: cat              AP:   0.7808  -------
# -------  Class: chair            AP:   0.5996  -------
# -------  Class: cow              AP:   0.4826  -------
# -------  Class: diningtable      AP:   0.5665  -------
# -------  Class: dog              AP:   0.6924  -------
# -------  Class: horse            AP:   0.7577  -------
# -------  Class: motorbike        AP:   0.8230  -------
# -------  Class: person           AP:   0.9024  -------
# -------  Class: pottedplant      AP:   0.4218  -------
# -------  Class: sheep            AP:   0.6269  -------
# -------  Class: sofa             AP:   0.5529  -------
# -------  Class: train            AP:   0.8875  -------
# -------  Class: tvmonitor        AP:   0.6293  -------
# mAP: 0.6859
# Avg loss: 0.15649321558428744
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.6858999533515671
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.02234013006091118
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.018943671137094498
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.0302626583725214
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.017930585891008377
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.01758778840303421
# -------  Class: aeroplane        AP:   0.8138  -------
# -------  Class: bicycle          AP:   0.6992  -------
# -------  Class: bird             AP:   0.8305  -------
# -------  Class: boat             AP:   0.7578  -------
# -------  Class: bottle           AP:   0.3877  -------
# -------  Class: bus              AP:   0.6183  -------
# -------  Class: car              AP:   0.8146  -------
# -------  Class: cat              AP:   0.7741  -------
# -------  Class: chair            AP:   0.5804  -------
# -------  Class: cow              AP:   0.5105  -------
# -------  Class: diningtable      AP:   0.5975  -------
# -------  Class: dog              AP:   0.7082  -------
# -------  Class: horse            AP:   0.7537  -------
# -------  Class: motorbike        AP:   0.8114  -------
# -------  Class: person           AP:   0.8963  -------
# -------  Class: pottedplant      AP:   0.3922  -------
# -------  Class: sheep            AP:   0.6175  -------
# -------  Class: sofa             AP:   0.5377  -------
# -------  Class: train            AP:   0.8749  -------
# -------  Class: tvmonitor        AP:   0.6318  -------
# mAP: 0.6804
# Avg loss: 0.1743260667312379
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.6804062895578615

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print("Test mAP: ", mAP_test)
# Out:
# -------  Class: aeroplane        AP:   0.7879  -------
# -------  Class: bicycle          AP:   0.7656  -------
# -------  Class: bird             AP:   0.8292  -------
# -------  Class: boat             AP:   0.7909  -------
# -------  Class: bottle           AP:   0.3263  -------
# -------  Class: bus              AP:   0.6931  -------
# -------  Class: car              AP:   0.8262  -------
# -------  Class: cat              AP:   0.7835  -------
# -------  Class: chair            AP:   0.5572  -------
# -------  Class: cow              AP:   0.5085  -------
# -------  Class: diningtable      AP:   0.6183  -------
# -------  Class: dog              AP:   0.7009  -------
# -------  Class: horse            AP:   0.8426  -------
# -------  Class: motorbike        AP:   0.7550  -------
# -------  Class: person           AP:   0.9119  -------
# -------  Class: pottedplant      AP:   0.4356  -------
# -------  Class: sheep            AP:   0.6366  -------
# -------  Class: sofa             AP:   0.5258  -------
# -------  Class: train            AP:   0.8660  -------
# -------  Class: tvmonitor        AP:   0.6241  -------
# mAP: 0.6893
# Avg loss: 0.17050790190696716
# Test mAP:  0.6892647974483737
